# %%
import os, sys, math
import numpy as np
import matplotlib.pyplot as plt

# %%
# fontsize: xx-small, x-small, small, medium, large, x-large, xx-large
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (8, 4),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'}

plt.rcParams.update(params)
#plt.rcParams.update(plt.rcParamsDefault)

# %%
val = {}
val["Stock-US"] = 35.0
val["Stock-Jpn/EU"] = 32.9
val["Stock-Emerging"] = 14.6
val["Bonds-US"] = 5
val["Bonds-PriceLinked"] = 0
val["Gold"] = 7.5
val["RealEstate"] = 5.0

# %%
label = list(val.keys())
v = np.array(list(val.values()))

# %%
plt.pie(v, labels=label, counterclock=False, startangle=90,
        wedgeprops={'linewidth': 1, 'edgecolor':"white"})

plt.tight_layout()

plt.savefig("wealthnavi_opt_portfolio_example.png")
